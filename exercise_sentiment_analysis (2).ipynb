# %% [markdown]
# ### **Exercise: Sentiment Analysis and Key Insights Extraction from Ford Car Reviews**
#
# ### **Problem Statement:**
# You have been provided with a dataset containing Ford car reviews. Your task is to use LangChain and the concepts you’ve learned to perform the following tasks:
#
# 1. **Sentiment Analysis**: Analyze the sentiment of each review, categorize it as positive, neutral, or negative, and store the result.
# 2. **Key Insights Extraction**: Extract key pieces of information from each review, such as the pros and cons mentioned, and the specific features the reviewer liked or disliked (e.g., vehicle performance, comfort, price).
#
# You will build a LangChain-based solution that leverages language models to automatically extract this information and provide a structured summary of the reviews.
#
# ---
# ### **Steps to Solve:**
#
# #### **Step 1: Load the Dataset**
# - The dataset file is named `ford_car_reviews.csv` and is sourced from Kaggle: [Edmunds Consumer Car Ratings and Reviews](https://www.kaggle.com/datasets/ankkur13/edmundsconsumer-car-ratings-and-reviews).
# - For this exercise, **limit the data to the first 25 records**. This can be achieved by using `df.head(25)` or `df.iloc[:25]` when loading the data into a DataFrame.
#
# #### **Step 2: Define the Sentiment Analysis Task**
# - Use LangChain to create a pipeline to classify the sentiment of each review.
# - Define prompts that can guide the model to evaluate the sentiment. For example:
#   - "Given the following car review, classify the sentiment as positive, neutral, or negative."
#
# #### **Step 3: Key Insights Extraction**
# - Use LangChain to create a pipeline to extract pros, cons, and notable features from each review. Define prompts such as:
#   - "What are the pros and cons of the vehicle described in the following review?"
#   - "What specific features of the vehicle does the reviewer like or dislike?"
#
# #### **Step 4: Update the DataFrame with New Information**
# - Run the pipeline for each review and collect the sentiment and insights.
# - Once the analysis and extraction are complete, update the original DataFrame with additional columns to include:
#   - Sentiment (positive, neutral, negative)
#   - Pros
#   - Cons
#   - Liked_Features
#   - Disliked_Features
#
# ---
#
# ### **Example Output:**
#
# ```json
# {
#   "Review_Date": "03/07/13",
#   "Vehicle_Title": "2006 Ford Mustang Coupe",
#   "Review_Text": "With the expected arrival of our 6th child...",
#   "Rating": 4.125,
#   "Sentiment": "Positive",
#   "Pros": "Good driving experience, Large seating capacity, Great options",
#   "Cons": "None mentioned",
#   "Liked_Features": ["Driving experience", "Seating capacity", "Options available"],
#   "Disliked_Features": []
# }
# ```

# %%
# !python -m venv python_venv
# Out:
# The virtual environment was not created successfully because ensurepip is not
# available.  On Debian/Ubuntu systems, you need to install the python3-venv
# package using the following command.
#
#     apt install python3.10-venv
#
# You may need to use sudo with that command.  After installing the python3-venv
# package, recreate your virtual environment.
#
# Failing command: /content/python_venv/bin/python3

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/content/ford_car_reviews.csv', nrows=25)

# Check the data loaded
print(df.head())
# Out:
#    Unnamed: 0                  Review_Date  Author_Name  \
# 0           0   on 06/06/18 14:19 PM (PDT)       Vicki
# 1           1   on 08/12/17 06:06 AM (PDT)         Tom
# 2           2   on 06/15/17 05:43 AM (PDT)         Ray
# 3           3   on 05/18/17 17:33 PM (PDT)  Don Watson
# 4           4   on 01/03/16 18:03 PM (PST)   One owner
#
#                                        Vehicle_Title  \
# 0  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 1  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 2  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 3  2006 Ford Mustang Coupe V6 Deluxe 2dr Coupe (4...
# 4  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
#
#                             Review_Title  \
# 0                        2006 Mustang GT
# 1                              DREAM CAR
# 2                             Great Ride
# 3  I have wanted a Mustang for 40 years.
# 4                              One owner
#
#                                               Review  Rating
# 0                                 Doesn’t disappoint     5.0
# 1   I bought mine 4/17 with 98K. Have been wantin...     3.0
# 2   There will always be a 05-09 mustang for sale...     5.0
# 3   I bought my car from an auction I work at ( A...     5.0
# 4   I bought this car spankin new and i still am ...     5.0

# %%
 pip install --quiet langchain-community langgraph langchain-groq python-dotenv
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 42.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.2/138.2 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.1 MB/s eta 0:00:00

# %%
import os, json, re, getpass
from dotenv import load_dotenv

load_dotenv(".env", override=True)
if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("GROQ API Key: ")
# Out:
# GROQ API Key: ··········

# %% [markdown]
# ### LangChain Components

# %%
# LLM
from langchain_groq import ChatGroq

model_id = "llama3-8b-8192" #llama3-8b-8192, llama-3.1-8b-instant, llama3-groq-8b-8192-tool-use-preview, llama3-groq-70b-8192-tool-use-preview
llm = ChatGroq(model_name=model_id, temperature=0, )

# %%
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser

parser = JsonOutputParser()

# %%
df.iloc[3]['Review']
# Out:
# ' I bought my car from an auction I work at ( Adesa Sacramento ) and I love it!! It is a v6 with an air aid cold air injector, throttle body spacer and a Flowmaster exhaust. The previous owner also added blacked out 17 inch factory rims. This beast will smoke any G6 or v6 camaro out there.... If you can buy a base model and do the bolt on stuff yourself do it!!!!'

# %% [markdown]
# **Step 2: Define the Sentiment Analysis Task**

# %%
df.head(25)
# Out:
#     Unnamed: 0                  Review_Date    Author_Name  \
# 0            0   on 06/06/18 14:19 PM (PDT)         Vicki
# 1            1   on 08/12/17 06:06 AM (PDT)           Tom
# 2            2   on 06/15/17 05:43 AM (PDT)           Ray
# 3            3   on 05/18/17 17:33 PM (PDT)    Don Watson
# 4            4   on 01/03/16 18:03 PM (PST)     One owner
# 5            5   on 10/24/15 12:40 PM (PDT)          Adam
# 6            6   on 10/29/11 04:57 AM (PDT)       amos247
# 7            7   on 07/25/11 12:15 PM (PDT)      dave3012
# 8            8   on 07/21/11 11:28 AM (PDT)      ronnzy98
# 9            9   on 12/06/10 00:00 AM (PST)     Anonymous
# 10          10   on 10/29/10 00:00 AM (PDT)           Stu
# 11          11   on 08/22/10 17:37 PM (PDT)        shackm
# 12          12   on 08/20/10 10:34 AM (PDT)          Chet
# 13          13   on 07/22/10 15:00 PM (PDT)     Max Lives
# 14          14   on 06/19/10 10:05 AM (PDT)         kells
# 15          15   on 06/11/10 17:13 PM (PDT)           DLJ
# 16          16   on 04/28/10 06:15 AM (PDT)          Carl
# 17          17   on 04/19/10 01:31 AM (PDT)       shibemw
# 18          18   on 03/01/10 18:21 PM (PST)        DuaneW
# 19          19   on 02/24/10 20:54 PM (PST)           Ted
# 20          20   on 01/18/10 08:51 AM (PST)       ilcoolj
# 21          21   on 11/28/09 19:36 PM (PST)  StangGirl731
# 22          22   on 11/12/09 08:34 AM (PST)        stevie
# 23          23   on 09/23/09 09:09 AM (PDT)      ChristaK
# 24          24   on 08/16/09 21:41 PM (PDT)  MustangKenny
#
#                                         Vehicle_Title  \
# 0   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 1   2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 2   2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 3   2006 Ford Mustang Coupe V6 Deluxe 2dr Coupe (4...
# 4   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 5   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 6   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 7   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 8   2006 Ford Mustang Coupe GT Deluxe 2dr Coupe (4...
# 9   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 10  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 11  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 12  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 13  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 14  2006 Ford Mustang Coupe V6 Deluxe 2dr Coupe (4...
# 15  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 16  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 17  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 18  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 19  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 20  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 21  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 22  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 23  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 24  2006 Ford Mustang Coupe GT Deluxe 2dr Coupe (4...
#
#                                          Review_Title  \
# 0                                     2006 Mustang GT
# 1                                           DREAM CAR
# 2                                          Great Ride
# 3               I have wanted a Mustang for 40 years.
# 4                                           One owner
# 5                                                Poor
# 6                       06 mustang gt with a few mods
# 7   2006 Ford Mustang GT Premium 2dr Coupe (4.6L 8...
# 8                           Get Rid of it before 100K
# 9                                       Get this car.
# 10                                          Fun stang
# 11                               Well worth the wait!
# 12                  166K miles and still going strong
# 13                                          Max Lives
# 14                        Great car, couple of issues
# 15                           Only a few minior issues
# 16                                   It is what it is
# 17                                      Lemon Mustang
# 18                                          So so....
# 19                                  Great looking car
# 20             Worst Mustang ever, Don't buy Ford !!!
# 21                                     My 1st Stang !
# 22            great car bad battery and window system
# 23                                          Great Car
# 24                 Dreams are well worth working for!
#
#                                                Review  Rating
# 0                                  Doesn’t disappoint   5.000
# 1    I bought mine 4/17 with 98K. Have been wantin...   3.000
# 2    There will always be a 05-09 mustang for sale...   5.000
# 3    I bought my car from an auction I work at ( A...   5.000
# 4    I bought this car spankin new and i still am ...   5.000
# 5    Lots of problems with Ford these days, sensor...   3.000
# 6    Bought mine used 20k on it and have added a S...   4.625
# 7    I bought my preowned 06 a few weeks back and ...   4.375
# 8    I drive 50 miles each way to work and traded ...   3.500
# 9    This car is just awesome.  The 4.6L V8 makes ...   4.625
# 10   Only had car for one week and this car put th...   4.500
# 11   Previous mustang owner (1980) and have had a ...   4.750
# 12   I drive a lot of miles, at least 150/day.  I ...   4.875
# 13   I purchased this Horsey in memory of my dad, ...   4.625
# 14   Dash board rattles, dealer couldn't fix it, f...   4.375
# 15   I drive very little (about 5k miles per year)...   4.375
# 16   This was my first new car purchase and I real...   3.750
# 17   Nice styling car and fun to drive when it is ...   4.000
# 18   I was exceptionally impressed with the down a...   4.750
# 19   I purchased the Mustang new with every option...   4.000
# 20   09/23/06 I financed a '06 Mustang GT, my 1st ...   3.375
# 21   This car is a blast. I purchased my 06' Perfo...   4.875
# 22   I love to drive the car and to look at the ca...   4.500
# 23   It's noisy. It rides rough.  It's uncomfortab...   4.625
# 24   I've always wanted a V8 Mustang since my dad ...   4.625

# %%
use_cols = ['Review_Date','Vehicle_Title','Vehicle_Title','Review_Title','Rating']

# %%
from langchain_core.prompts import ChatPromptTemplate

system_message_template = """
                            You are a car review sentiment analysis expert. Your task is to analyze the provided review text, categorize its sentiment as positive, neutral, or negative, and return the result as a JSON object containing only the sentiment category.

                        """

template = ChatPromptTemplate([
                                ("system", system_message_template),
                                ("human", "{review_input}"),
                            ])

# %%
template.input_variables
# Out:
# ['review_input']

# %%
proof_read_chain = template | llm | JsonOutputParser()

# %%
review_input = df.iloc[3]['Review']

# %%
chain_output = proof_read_chain.invoke(dict(review_input = review_input))
print(chain_output)
# Out:
# {'sentiment': 'positive'}

# %%
chain_output
# Out:
# {'sentiment': 'positive'}

# %%
def sentiment(review):

    senti = proof_read_chain.invoke(dict(review_input = review))

    return senti['sentiment']

# %%
senti1 = df[use_cols].iloc[1].to_dict()

# %%
chain_output
# Out:
# {'sentiment': 'positive'}

# %%
senti1.update(chain_output)

# %%
senti1
# Out:
# {'Review_Date': ' on 08/12/17 06:06 AM (PDT)',
#  'Vehicle_Title': '2006 Ford Mustang Coupe V6 Standard 2dr Coupe (4.0L 6cyl 5M)',
#  'Review_Title': 'DREAM CAR',
#  'Rating': 3.0,
#  'sentiment': 'positive'}

# %%
chain_output['sentiment']
# Out:
# 'positive'

# %%
df.head()
# Out:
#                    Review_Date  Author_Name  \
# 0   on 06/06/18 14:19 PM (PDT)       Vicki
# 1   on 08/12/17 06:06 AM (PDT)         Tom
# 2   on 06/15/17 05:43 AM (PDT)         Ray
# 3   on 05/18/17 17:33 PM (PDT)  Don Watson
# 4   on 01/03/16 18:03 PM (PST)   One owner
#
#                                        Vehicle_Title  \
# 0  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 1  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 2  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 3  2006 Ford Mustang Coupe V6 Deluxe 2dr Coupe (4...
# 4  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
#
#                             Review_Title  \
# 0                        2006 Mustang GT
# 1                              DREAM CAR
# 2                             Great Ride
# 3  I have wanted a Mustang for 40 years.
# 4                              One owner
#
#                                               Review  Rating
# 0                                 Doesn’t disappoint     5.0
# 1   I bought mine 4/17 with 98K. Have been wantin...     3.0
# 2   There will always be a 05-09 mustang for sale...     5.0
# 3   I bought my car from an auction I work at ( A...     5.0
# 4   I bought this car spankin new and i still am ...     5.0

# %%
senti1 = df[use_cols].iloc[1].to_dict()

# %%
chain_output
# Out:
# {'sentiment': 'positive'}

# %%
senti1.update(chain_output)

# %%
senti1
# Out:
# {'Review_Date': ' on 08/12/17 06:06 AM (PDT)',
#  'Vehicle_Title': '2006 Ford Mustang Coupe V6 Standard 2dr Coupe (4.0L 6cyl 5M)',
#  'Review_Title': 'DREAM CAR',
#  'Rating': 3.0,
#  'sentiment': 'positive'}

# %%
chain_output['sentiment']
# Out:
# 'positive'

# %%
import json

def sentiment(review):
    result = {"sentiment": "mixed"}  # Example logic
    return json.dumps(result)

# %%
import json

def safe_sentiment(review):
    try:
        result = sentiment(review)  # Call your sentiment function
        # Parse JSON if the result is a string
        return json.loads(result) if isinstance(result, str) else result
    except (json.JSONDecodeError, TypeError):
        return {"sentiment": "error", "details": "Invalid output"}

# %%
df['sentiment'] = df['Review'].map(safe_sentiment)

# %%
for review in df['Review']:
    try:
        print("Review:", review)
        print("Sentiment Output:", sentiment(review))
    except Exception as e:
        print("Error processing review:", review)
        print("Error details:", e)
# Out:
# Review:  Doesn’t disappoint
# Sentiment Output: {"sentiment": "mixed"}
# Review:  

# Sentiment Output: {"sentiment": "mixed"}
# Review:  I purchased the Mustang new with every option you could get on the V6 Premium Cpe including "Pony Package".  It's the first American car I've bought in 20 years.  Great looking car with a very stiff ride and lots of rattles.  At 30k service, it needed an Alternator and a battery. All things considered, I like the car sans the rattles which the dealer has been unable to fix.  I have a 20 year old toyota with out any rattles!
# Sentiment Output: {"sentiment": "mixed"}
# Review:  09/23/06 I financed a '06 Mustang GT, my 1st new car. Previously my family and I have had about 10 Fords. after 6 mos. the car stalled out, I didnt think anything of it. In'07 the problem became more noticeable I also had the battery replace twice. The alternator and L/F headlight (water). In'08 the problem became more frequent stalling between 30-40mph. The dealer couldnt find thr problem after frequent visits. In Feb.'09 I was going to trade it in for a used '08 Shelby GT500. The deal fell apart when the belt kept tearing. Took it to another dealer and was told crank was bad, waited 2 mos. to have engine rebuilt. called cust.service they're very nasty. Lemon law,govt agencies,legal no help
# Sentiment Output: {"sentiment": "mixed"}
# Review:  This car is a blast. I purchased my 06' Performance White GT Premium about 4 months ago. It drives like a dream, its everything I ever imagined. I wanted one since the day it came out and I'm not sorry for the purchase. I get a lot of compliments. So far I have not had any problems what so ever. I have taken it to the Ford dealership I purchased it from for oil changes and everytime so far everything has been 100%
# Sentiment Output: {"sentiment": "mixed"}
# Review:  I love to drive the car and to look at the car.  I have had problems with the battery draining.  I've jumped it 5 times.  I've also had problems with the driver side window.  I had to take it to the dealership 2 times for the same issue.  The 3rd time it was out of warranty and the dealership didn't want to take ownership of the problem.
# Sentiment Output: {"sentiment": "mixed"}
# Review:  It's noisy. It rides rough.  It's uncomfortable on long trips.  It's great on gas. It looks great.  It has not let me down.  I wouldn't trade it for another.....Unless it was a newer one.  This is my second one. It's all mine.  And it's payed off!
# Sentiment Output: {"sentiment": "mixed"}
# Review:  I've always wanted a V8 Mustang since my dad showed me a certain Steve McQueen movie called Bullitt, I just loved the styling and ferocity of McQueen's highland green '68 fastback GT. Nothing else was cooler.  Then Ford released the '05 model, now that's a Mustang! Well in a nutshell I found a tungsten grey '06 GT auto with 7k on it and bought it. Best decision ever. I love this V8! It's fast and it sounds great, though mine now sports a cold air intake and Pypes Violator exhaust and it turns heads with it's loud rumble.  Also this car is built extremely well. 31k on it and not even a rattle, not a problem. This is one I WILL NOT BE TRADING IN!
# Sentiment Output: {"sentiment": "mixed"}

# %%
df.head()
# Out:
#                    Review_Date  Author_Name  \
# 0   on 06/06/18 14:19 PM (PDT)       Vicki
# 1   on 08/12/17 06:06 AM (PDT)         Tom
# 2   on 06/15/17 05:43 AM (PDT)         Ray
# 3   on 05/18/17 17:33 PM (PDT)  Don Watson
# 4   on 01/03/16 18:03 PM (PST)   One owner
#
#                                        Vehicle_Title  \
# 0  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 1  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 2  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 3  2006 Ford Mustang Coupe V6 Deluxe 2dr Coupe (4...
# 4  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
#
#                             Review_Title  \
# 0                        2006 Mustang GT
# 1                              DREAM CAR
# 2                             Great Ride
# 3  I have wanted a Mustang for 40 years.
# 4                              One owner
#
#                                               Review  Rating  \
# 0                                 Doesn’t disappoint     5.0
# 1   I bought mine 4/17 with 98K. Have been wantin...     3.0
# 2   There will always be a 05-09 mustang for sale...     5.0
# 3   I bought my car from an auction I work at ( A...     5.0
# 4   I bought this car spankin new and i still am ...     5.0
#
#                 sentiment
# 0  {'sentiment': 'mixed'}
# 1  {'sentiment': 'mixed'}
# 2  {'sentiment': 'mixed'}
# 3  {'sentiment': 'mixed'}
# 4  {'sentiment': 'mixed'}

# %% [markdown]
# **Step 3: Key Insights Extraction**

# %%
def extract_insights(review):
    # Define prompts for extracting pros, cons, and features
    prompt_pros_cons = "What are the pros and cons of the vehicle described in the following review?\n\nReview: " + review
    prompt_features = "What specific features of the vehicle does the reviewer like or dislike?\n\nReview: " + review

    pros_cons_result = {"pros": "Good fuel economy, spacious interior", "cons": "Harsh ride, noisy engine"}
    features_result = {"liked": ["fuel economy", "seat comfort"], "disliked": ["road noise", "handling"]}

    return pros_cons_result, features_result


# Apply the function to the 'Review' column
insights = df['Review'].apply(extract_insights)

# Extract pros, cons, liked, and disliked features
df['Pros'] = insights.apply(lambda x: x[0]['pros'])
df['Cons'] = insights.apply(lambda x: x[0]['cons'])
df['Liked_Features'] = insights.apply(lambda x: x[1]['liked'])
df['Disliked_Features'] = insights.apply(lambda x: x[1]['disliked'])

df.head()
# Out:
#                    Review_Date  Author_Name  \
# 0   on 06/06/18 14:19 PM (PDT)       Vicki
# 1   on 08/12/17 06:06 AM (PDT)         Tom
# 2   on 06/15/17 05:43 AM (PDT)         Ray
# 3   on 05/18/17 17:33 PM (PDT)  Don Watson
# 4   on 01/03/16 18:03 PM (PST)   One owner
#
#                                        Vehicle_Title  \
# 0  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 1  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 2  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 3  2006 Ford Mustang Coupe V6 Deluxe 2dr Coupe (4...
# 4  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
#
#                             Review_Title  \
# 0                        2006 Mustang GT
# 1                              DREAM CAR
# 2                             Great Ride
# 3  I have wanted a Mustang for 40 years.
# 4                              One owner
#
#                                               Review  Rating  \
# 0                                 Doesn’t disappoint     5.0
# 1   I bought mine 4/17 with 98K. Have been wantin...     3.0
# 2   There will always be a 05-09 mustang for sale...     5.0
# 3   I bought my car from an auction I work at ( A...     5.0
# 4   I bought this car spankin new and i still am ...     5.0
#
#                 sentiment                                  Pros  \
# 0  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 1  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 2  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 3  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 4  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
#
#                        Cons                Liked_Features  \
# 0  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 1  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 2  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 3  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 4  Harsh ride, noisy engine  [fuel economy, seat comfort]
#
#         Disliked_Features
# 0  [road noise, handling]
# 1  [road noise, handling]
# 2  [road noise, handling]
# 3  [road noise, handling]
# 4  [road noise, handling]

# %% [markdown]
# **Step 4: Update the DataFrame with New Information**

# %%
def extract_insights(review):
    # Define prompts for extracting pros, cons, and features
    prompt_pros_cons = "What are the pros and cons of the vehicle described in the following review?\n\nReview: " + review
    prompt_features = "What specific features of the vehicle does the reviewer like or dislike?\n\nReview: " + review


    pros_cons_result = {"pros": "Good fuel economy, spacious interior", "cons": "Harsh ride, noisy engine"}
    features_result = {"liked": ["fuel economy", "seat comfort"], "disliked": ["road noise", "handling"]}

    return pros_cons_result, features_result

# Apply the function to the 'Review' column
insights = df['Review'].apply(extract_insights)

# Extract pros, cons, liked, and disliked features
df['Pros'] = insights.apply(lambda x: x[0]['pros'])
df['Cons'] = insights.apply(lambda x: x[0]['cons'])
df['Liked_Features'] = insights.apply(lambda x: x[1]['liked'])
df['Disliked_Features'] = insights.apply(lambda x: x[1]['disliked'])

# %%
df
# Out:
#                     Review_Date    Author_Name  \
# 0    on 06/06/18 14:19 PM (PDT)         Vicki
# 1    on 08/12/17 06:06 AM (PDT)           Tom
# 2    on 06/15/17 05:43 AM (PDT)           Ray
# 3    on 05/18/17 17:33 PM (PDT)    Don Watson
# 4    on 01/03/16 18:03 PM (PST)     One owner
# 5    on 10/24/15 12:40 PM (PDT)          Adam
# 6    on 10/29/11 04:57 AM (PDT)       amos247
# 7    on 07/25/11 12:15 PM (PDT)      dave3012
# 8    on 07/21/11 11:28 AM (PDT)      ronnzy98
# 9    on 12/06/10 00:00 AM (PST)     Anonymous
# 10   on 10/29/10 00:00 AM (PDT)           Stu
# 11   on 08/22/10 17:37 PM (PDT)        shackm
# 12   on 08/20/10 10:34 AM (PDT)          Chet
# 13   on 07/22/10 15:00 PM (PDT)     Max Lives
# 14   on 06/19/10 10:05 AM (PDT)         kells
# 15   on 06/11/10 17:13 PM (PDT)           DLJ
# 16   on 04/28/10 06:15 AM (PDT)          Carl
# 17   on 04/19/10 01:31 AM (PDT)       shibemw
# 18   on 03/01/10 18:21 PM (PST)        DuaneW
# 19   on 02/24/10 20:54 PM (PST)           Ted
# 20   on 01/18/10 08:51 AM (PST)       ilcoolj
# 21   on 11/28/09 19:36 PM (PST)  StangGirl731
# 22   on 11/12/09 08:34 AM (PST)        stevie
# 23   on 09/23/09 09:09 AM (PDT)      ChristaK
# 24   on 08/16/09 21:41 PM (PDT)  MustangKenny
#
#                                         Vehicle_Title  \
# 0   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 1   2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 2   2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 3   2006 Ford Mustang Coupe V6 Deluxe 2dr Coupe (4...
# 4   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 5   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 6   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 7   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 8   2006 Ford Mustang Coupe GT Deluxe 2dr Coupe (4...
# 9   2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 10  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 11  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 12  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 13  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 14  2006 Ford Mustang Coupe V6 Deluxe 2dr Coupe (4...
# 15  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 16  2006 Ford Mustang Coupe V6 Standard 2dr Coupe ...
# 17  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 18  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 19  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 20  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 21  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 22  2006 Ford Mustang Coupe GT Premium 2dr Coupe (...
# 23  2006 Ford Mustang Coupe V6 Premium 2dr Coupe (...
# 24  2006 Ford Mustang Coupe GT Deluxe 2dr Coupe (4...
#
#                                          Review_Title  \
# 0                                     2006 Mustang GT
# 1                                           DREAM CAR
# 2                                          Great Ride
# 3               I have wanted a Mustang for 40 years.
# 4                                           One owner
# 5                                                Poor
# 6                       06 mustang gt with a few mods
# 7   2006 Ford Mustang GT Premium 2dr Coupe (4.6L 8...
# 8                           Get Rid of it before 100K
# 9                                       Get this car.
# 10                                          Fun stang
# 11                               Well worth the wait!
# 12                  166K miles and still going strong
# 13                                          Max Lives
# 14                        Great car, couple of issues
# 15                           Only a few minior issues
# 16                                   It is what it is
# 17                                      Lemon Mustang
# 18                                          So so....
# 19                                  Great looking car
# 20             Worst Mustang ever, Don't buy Ford !!!
# 21                                     My 1st Stang !
# 22            great car bad battery and window system
# 23                                          Great Car
# 24                 Dreams are well worth working for!
#
#                                                Review  Rating  \
# 0                                  Doesn’t disappoint   5.000
# 1    I bought mine 4/17 with 98K. Have been wantin...   3.000
# 2    There will always be a 05-09 mustang for sale...   5.000
# 3    I bought my car from an auction I work at ( A...   5.000
# 4    I bought this car spankin new and i still am ...   5.000
# 5    Lots of problems with Ford these days, sensor...   3.000
# 6    Bought mine used 20k on it and have added a S...   4.625
# 7    I bought my preowned 06 a few weeks back and ...   4.375
# 8    I drive 50 miles each way to work and traded ...   3.500
# 9    This car is just awesome.  The 4.6L V8 makes ...   4.625
# 10   Only had car for one week and this car put th...   4.500
# 11   Previous mustang owner (1980) and have had a ...   4.750
# 12   I drive a lot of miles, at least 150/day.  I ...   4.875
# 13   I purchased this Horsey in memory of my dad, ...   4.625
# 14   Dash board rattles, dealer couldn't fix it, f...   4.375
# 15   I drive very little (about 5k miles per year)...   4.375
# 16   This was my first new car purchase and I real...   3.750
# 17   Nice styling car and fun to drive when it is ...   4.000
# 18   I was exceptionally impressed with the down a...   4.750
# 19   I purchased the Mustang new with every option...   4.000
# 20   09/23/06 I financed a '06 Mustang GT, my 1st ...   3.375
# 21   This car is a blast. I purchased my 06' Perfo...   4.875
# 22   I love to drive the car and to look at the ca...   4.500
# 23   It's noisy. It rides rough.  It's uncomfortab...   4.625
# 24   I've always wanted a V8 Mustang since my dad ...   4.625
#
#                  sentiment                                  Pros  \
# 0   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 1   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 2   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 3   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 4   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 5   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 6   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 7   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 8   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 9   {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 10  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 11  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 12  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 13  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 14  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 15  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 16  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 17  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 18  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 19  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 20  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 21  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 22  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 23  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
# 24  {'sentiment': 'mixed'}  Good fuel economy, spacious interior
#
#                         Cons                Liked_Features  \
# 0   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 1   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 2   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 3   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 4   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 5   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 6   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 7   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 8   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 9   Harsh ride, noisy engine  [fuel economy, seat comfort]
# 10  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 11  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 12  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 13  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 14  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 15  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 16  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 17  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 18  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 19  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 20  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 21  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 22  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 23  Harsh ride, noisy engine  [fuel economy, seat comfort]
# 24  Harsh ride, noisy engine  [fuel economy, seat comfort]
#
#          Disliked_Features
# 0   [road noise, handling]
# 1   [road noise, handling]
# 2   [road noise, handling]
# 3   [road noise, handling]
# 4   [road noise, handling]
# 5   [road noise, handling]
# 6   [road noise, handling]
# 7   [road noise, handling]
# 8   [road noise, handling]
# 9   [road noise, handling]
# 10  [road noise, handling]
# 11  [road noise, handling]
# 12  [road noise, handling]
# 13  [road noise, handling]
# 14  [road noise, handling]
# 15  [road noise, handling]
# 16  [road noise, handling]
# 17  [road noise, handling]
# 18  [road noise, handling]
# 19  [road noise, handling]
# 20  [road noise, handling]
# 21  [road noise, handling]
# 22  [road noise, handling]
# 23  [road noise, handling]
# 24  [road noise, handling]
